# %%
import os
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as tv
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from PIL import Image
import logging
import matplotlib.pyplot as plt
import copy
import pandas as pd
# %matplotlib inline

# %%
mylogs = logging.getLogger()
mylogs.setLevel(logging.INFO)
# Logging to file
file = logging.FileHandler("training.log", mode='w')
file.setLevel(logging.INFO)
fileformat = logging.Formatter("%(asctime)s:%(levelname)s:%(message)s",datefmt="%H:%M:%S")
file.setFormatter(fileformat)
mylogs.addHandler(file)
# Logging to console
stream = logging.StreamHandler()
stream.setLevel(logging.INFO)
mylogs.addHandler(stream)

# %% [markdown]
# # Paths and parameters

# %%
test_mask_dir = None
train_img_dir= r"E:/ct_multi_segmentation/train/images/"
train_mask_dir =  r"E:/ct_multi_segmentation/train/masks/"
test_img_dir = r"E:/ct_multi_segmentation/test/images/"
test_mask_dir = r"E:/ct_multi_segmentation/test/masks/"
model_name = 'Unet'
project_name = "CT_multi_class_segmentation"
resize_size = (224, 224)
label_values = (32768, 32769, 32770, 32771, 32773)
num_categories = len(label_values)
n_channels = 1

# %% [markdown]
# # Creating list of images and masks

# %%
def create_img_list(img_folder):
    img_list = []
    for (dirpath, dirnames, filenames) in os.walk(img_folder):
        img_list += [os.path.join(dirpath, file) for file in filenames]
    return img_list

# %%
train_img_list = create_img_list(train_img_dir)
test_img_list = create_img_list(test_img_dir)

if train_mask_dir:
    train_mask_img_list = create_img_list(train_mask_dir)
if test_mask_dir:
    test_mask_img_list = create_img_list(test_mask_dir)

# %%
def make_img_mask_pairs(img_list, mask_list):
    img_path_names =  {os.path.basename(n):n for n in img_list}
    mask_path_names =  {os.path.basename(n):n for n in mask_list}
    img_mask_pairs = {}
    for name, path in img_path_names.items():
        if name in mask_path_names.keys():
            img_mask_pairs[path] = mask_path_names[name]
    return(img_mask_pairs)

# %%
train_img_mask_pairs = make_img_mask_pairs(train_img_list,train_mask_img_list)

# %%
test_img_mask_pairs = make_img_mask_pairs(test_img_list,test_mask_img_list)

# %%
def train_val_split(img_dic, split_ratio):
    val_dic = {}
    train_dic = {}
    for i in range(int(len(img_dic)*split_ratio)):
        random_entry = random.choice(list(img_dic.keys()))
        val_dic[random_entry] = img_dic[random_entry]    
    for key in img_dic.keys():
        if key not in val_dic.keys():
            train_dic[key] = img_dic[key]
    return(train_dic, val_dic)

# %%
train_img_mask_pairs, val_img_mask_pairs = train_val_split(train_img_mask_pairs, 0.2)

# %% [markdown]
# # Image Loading functions

# %%
def get_img_transform():
    return tv.Compose([
        tv.ToTensor(),
        tv.Normalize((0), (1)),
    ])
def get_mask_transform():
    return tv.Compose([
        tv.ToTensor(),
    ])
transforms = (get_img_transform(),get_mask_transform())

# %%
class loadDataset(Dataset):
    def __init__(self,img_mask_pairs_dic, transforms, label_values):
        super().__init__()
        self.imgs = list(img_mask_pairs_dic.keys())
        self.masks = list(img_mask_pairs_dic.values())
        self.img_transform = transforms[0]
        self.mask_transform = transforms[1]
        self.label_values = label_values
        
    def __getitem__(self, idx):
        image_path = self.imgs[idx]
        mask_path = self.masks[idx]
      ### Reading, converting and normalizing image
        ### Reading, converting and normalizing image
        img = Image.open(image_path)
        img = img.resize((resize_size[0], resize_size[1]))
        ### Doing the same for mask
        mask = Image.open(mask_path)
        mask = mask.resize((resize_size[0], resize_size[1]))
        mask = np.asarray(mask)
        # one hode encode mask
        # from https://github.com/cm-amaya/UNet_Multiclass/blob/master/data_loader.py
        masks = [(mask == v) for v in self.label_values]

        mask = np.stack(masks, axis=-1).astype('bool')
        ### Apply Transforms on image
        img = self.img_transform(img)
            # creating mask tensor as a label
        transformed_mask  = self.mask_transform(mask)
        return img.float(), transformed_mask.float(), mask

    def __len__(self):
        return len(self.imgs)

# %%
train_dataset = loadDataset(train_img_mask_pairs, transforms, label_values)
val_dataset = loadDataset(val_img_mask_pairs, transforms, label_values)
test_dataset = loadDataset(test_img_mask_pairs, transforms, label_values)

# %%
train_data_loader = DataLoader(
    dataset = train_dataset,
    num_workers = 0,
    batch_size = 4,
    shuffle = True
)
val_data_loader = DataLoader(
    dataset = val_dataset,
    num_workers = 0,
    batch_size = 2,
    shuffle = True
)
test_data_loader = DataLoader(
    dataset = test_dataset,
    num_workers = 0,
    batch_size = 1,
    shuffle = True
)

# %%
def apply_color_masks(image, mask, num_categories):
    color_to_categories = ((0,0,100), (0,100,0), (100,0,0), (100,100,0), (100,0,100), 
                           (0,100,100), (100,100,100))
    image = image.numpy()
    mask = mask.numpy()
    image = image.squeeze()
    mask = mask.squeeze()
    mask = np.argmax(mask, axis=2)
    
    image = np.stack((image,)*3, axis=-1)
    mask = np.stack((mask,)*3, axis=-1)
    
    masked_image = copy.deepcopy(image)
    

    # select category channel
    for category in range(len(num_categories)):
        if category:
            masked_image[:,:,0][mask[:,:,0]==category] = color_to_categories[category][0]
            masked_image[:,:,1][mask[:,:,0]==category] = color_to_categories[category][1]
            masked_image[:,:,2][mask[:,:,0]==category] = color_to_categories[category][2]

    return image, masked_image

# %%
  def dataset_preview(train_data_loader, num_categories):
    for image, _, mask in train_data_loader:
        # Selecting a chanel for a mask
        image, masked_image = apply_color_masks(image, mask, num_categories)
        image = torch.from_numpy(image)
        masked_image = torch.from_numpy(masked_image)
 
        imgs = [image, masked_image]
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        n_row = 1
        n_col = 2
        _, axs = plt.subplots(n_row, n_col, figsize=(18, 18))
        axs = axs.flatten()
        titles = [' Image', 'Image with mask']
        for title, img, ax in zip(titles, imgs, axs):
            ax.imshow(make_grid(img, 4))
            ax.set_title(title)
        plt.show()
        break
        
dataset_preview(test_data_loader,label_values)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Functions for training

# %%
# https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_model.py
from UNet import UNet
model = UNet(n_channels, num_categories)

# %%
#from https://www.kaggle.com/bigironsphere/loss-function-library-keras-pytorch
class DiceBCELoss(nn.Module):
    # Return Dice and Dice loss
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()
        dice_coefficient =  (2. * intersection + smooth) / (torch.sum(targets) + torch.sum(inputs) + smooth)
        
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss
        
        return Dice_BCE, dice_coefficient

# %%
class Optimizer:
    def __init__(self, model):
        self.optimizer_dict = {}
        self.optimizer_dict['optimizer'] = torch.optim.Adam(model.parameters(), lr = 0.0001)
        self.optimizer_dict['lr_scheduler'] = torch.optim.lr_scheduler.StepLR(self.optimizer_dict['optimizer'], step_size = 5, gamma = 0.5)
        self.optimizer_dict['criterion'] = DiceBCELoss(nn.Module)

    def return_state_dict(self):
        return self.optimizer_dict['optimizer'].state_dict()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
optimizerA = Optimizer(model)

# %%
mylogs.info("Model: " + model_name )
# Loading model to device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
mylogs.info(f"Device is: {str(device)}")
model.to(device)
optimizerA = Optimizer(model)
#model = nn.DataParallel(model)
# Out:
# Model: Unet
# Device is: cuda

# %%
def train_one_epoch(data_loader, optimizer_obj, phase):
    ## global to local
    optimizer = optimizer_obj.optimizer_dict['optimizer']
    criterion = optimizer_obj.optimizer_dict['criterion']
    lr_scheduler = optimizer_obj.optimizer_dict['criterion'] 
    ### Local Parameters
    epoch_loss = []
    epoch_dice = []
    start_time = time.time()
    
    ###Iterating over data loader
    for images, labels, _ in data_loader:
        #Loading images and labels to device
        images = images.to(device)
        labels = labels.to(device)
        #Reseting Gradients
        optimizer.zero_grad()
        #Forward
        preds = model(images)
        #Calculating Loss
        _loss, dice_coefficient = criterion(preds, labels)
        loss = _loss.item()
        epoch_loss.append(float(loss))
        epoch_dice.append(float(dice_coefficient))
        #Backward if train phase
        if phase == "train":
            _loss.backward()
            optimizer.step()
    ###Overall Epoch Results
    end_time = time.time()
    total_time = int(end_time - start_time)/60
    ###Dice coefficient and Loss
    epoch_loss = np.mean(epoch_loss)
    epoch_dice = np.mean(epoch_dice)
    ###Storing results to logs
    return epoch_loss, epoch_dice, total_time

# %%
def report_in_progress(phase, epoch, loss, dice, _time):
       #Print epoch details
        mylogs.info(f'{"Training" if phase == False else "Validation"} Epoch {epoch}: | Loss: {loss:.5f} | Dice: {dice:.3f} | Time: {(round(_time, 4))}')

# %%
def train_model(model, optimizer_obj, max_n_epochs, early_stop_epoch_thresh = 20):
    start_time = time.time()
    # initializing  training stats
    train_logs =  {"loss" : [], "dice coefficient" : [], "time" : []}
    val_logs = {"loss" : [], "dice coefficient" : [], "time" : []} 
    mylogs.info("Training started")
    best_model = model
    best_epoch = 1
    best_val_dice = 0
    bad_dice_epoch = 0
    current_epoch = 0
    best_train_logs = {}
    best_val_logs = {}
    best_model_optimizer_state_dict = optimizer_obj.return_state_dict()
    for epoch in range(1, max_n_epochs + 1):
        if bad_dice_epoch < early_stop_epoch_thresh:
            current_epoch = epoch 
            ###Training
            train_loss, train_dice, train_time = train_one_epoch(train_data_loader, optimizer_obj, "train")
            #Print train Epoch Details      
            report_in_progress(0, epoch, train_loss, train_dice, train_time)
            #Adding stats for the epoch
            train_logs["loss"].append(train_loss)
            train_logs["dice coefficient"].append(train_dice)
            train_logs["time"].append(train_time)
            ###Validation
            val_loss, val_dice, val_time = train_one_epoch(val_data_loader, optimizer_obj, "validation")
            #Print Val Epoch  Details
            report_in_progress(1, epoch, val_loss, val_dice, val_time)
            #adding stats on the epoch
            val_logs["loss"].append(val_loss)
            val_logs["dice coefficient"].append(val_dice)
            val_logs["time"].append(val_time)
            # Early stop processing
            if val_dice > best_val_dice:
                best_val_dice = val_dice
                best_model = copy.deepcopy(model)
                bad_dice_epoch = 0
                best_train_logs = train_logs
                best_val_logs = val_logs
                best_epoch = epoch 
            else:
                bad_dice_epoch +=1
        else:
            mylogs.info(f"Early stop, best dice coefficient: {best_val_dice}%")
            break
    end_time = time.time()
    total_time = end_time - start_time
    mylogs.info(f"Total time : {int(total_time/60)}")
    # packing training data into a dictionary
    training_stats = {}
    training_stats['train logs'] = train_logs
    training_stats['validation logs'] = val_logs
    training_stats['best train logs'] = best_train_logs
    training_stats['best validation logs'] = best_val_logs
    training_stats['best validation dice'] = best_val_dice
    training_stats['best epoch'] = best_epoch
    training_stats['current epoch'] = current_epoch 
    
    return best_model, best_model_optimizer_state_dict, training_stats

# %%
# Training de novo
n_of_epochs = 200
model, model_optimizer_state_dict,  training_stats = train_model(model, optimizerA, n_of_epochs)
# Out:
# Training started
# Training Epoch 1: | Loss: 0.87806 | Dice: 0.413 | Time: 3.15
# Validation Epoch 1: | Loss: 0.65947 | Dice: 0.519 | Time: 0.3
# Training Epoch 2: | Loss: 0.39610 | Dice: 0.694 | Time: 3.5
# Validation Epoch 2: | Loss: 0.43574 | Dice: 0.654 | Time: 0.3
# Training Epoch 3: | Loss: 0.20666 | Dice: 0.836 | Time: 4.4
# Validation Epoch 3: | Loss: 0.35999 | Dice: 0.696 | Time: 0.4
# Training Epoch 4: | Loss: 0.15756 | Dice: 0.871 | Time: 4.4833
# Validation Epoch 4: | Loss: 0.34653 | Dice: 0.699 | Time: 0.4333
# Training Epoch 5: | Loss: 0.12711 | Dice: 0.895 | Time: 3.9833
# Validation Epoch 5: | Loss: 0.26999 | Dice: 0.760 | Time: 0.35
# Training Epoch 6: | Loss: 0.09428 | Dice: 0.919 | Time: 3.7167
# Validation Epoch 6: | Loss: 0.27254 | Dice: 0.751 | Time: 0.4
# Training Epoch 7: | Loss: 0.09098 | Dice: 0.922 | Time: 4.25
# Validation Epoch 7: | Loss: 0.27624 | Dice: 0.746 | Time: 0.35
# Training Epoch 8: | Loss: 0.07802 | Dice: 0.931 | Time: 3.95
# Validation Epoch 8: | Loss: 0.27145 | Dice: 0.747 | Time: 0.3167
# Training Epoch 9: | Loss: 0.09112 | Dice: 0.921 | Time: 3.75
# Validation Epoch 9: | Loss: 0.27049 | Dice: 0.749 | Time: 0.3167
# Training Epoch 10: | Loss: 0.07077 | Dice: 0.937 | Time: 3.7333
# Validation Epoch 10: | Loss: 0.25402 | Dice: 0.759 | Time: 0.3333
# Training Epoch 11: | Loss: 0.07691 | Dice: 0.935 | Time: 3.7333
# Validation Epoch 11: | Loss: 0.27390 | Dice: 0.753 | Time: 0.3667
# Training Epoch 12: | Loss: 0.08381 | Dice: 0.923 | Time: 3.6833
# Validation Epoch 12: | Loss: 0.26761 | Dice: 0.744 | Time: 0.4
# Training Epoch 13: | Loss: 0.07278 | Dice: 0.933 | Time: 3.6833
# Validation Epoch 13: | Loss: 0.24951 | Dice: 0.759 | Time: 0.35
# Training Epoch 14: | Loss: 0.08410 | Dice: 0.924 | Time: 3.7667
# Validation Epoch 14: | Loss: 0.23517 | Dice: 0.774 | Time: 0.2667
# Training Epoch 15: | Loss: 0.06433 | Dice: 0.944 | Time: 3.8333
# Validation Epoch 15: | Loss: 0.23489 | Dice: 0.779 | Time: 0.35
# Training Epoch 16: | Loss: 0.06963 | Dice: 0.936 | Time: 3.7667
# Validation Epoch 16: | Loss: 0.24538 | Dice: 0.762 | Time: 0.3667
# Training Epoch 17: | Loss: 0.06758 | Dice: 0.939 | Time: 3.8167
# Validation Epoch 17: | Loss: 0.26003 | Dice: 0.751 | Time: 0.2667
# Training Epoch 18: | Loss: 0.06431 | Dice: 0.940 | Time: 3.9
# Validation Epoch 18: | Loss: 0.23648 | Dice: 0.769 | Time: 0.2833
# Training Epoch 19: | Loss: 0.07297 | Dice: 0.931 | Time: 3.8833
# Validation Epoch 19: | Loss: 0.21918 | Dice: 0.786 | Time: 0.4
# Training Epoch 20: | Loss: 0.06237 | Dice: 0.941 | Time: 3.8833
# Validation Epoch 20: | Loss: 0.24641 | Dice: 0.760 | Time: 0.2667
# Training Epoch 21: | Loss: 0.05546 | Dice: 0.948 | Time: 3.9667
# Validation Epoch 21: | Loss: 0.23770 | Dice: 0.771 | Time: 0.2667
# Training Epoch 22: | Loss: 0.05826 | Dice: 0.947 | Time: 4.0333
# Validation Epoch 22: | Loss: 0.25281 | Dice: 0.753 | Time: 0.2667
# Training Epoch 23: | Loss: 0.07197 | Dice: 0.932 | Time: 3.9333
# Validation Epoch 23: | Loss: 0.24827 | Dice: 0.757 | Time: 0.4
# Training Epoch 24: | Loss: 0.06403 | Dice: 0.943 | Time: 3.9333
# Validation Epoch 24: | Loss: 0.22655 | Dice: 0.782 | Time: 0.2667
# Training Epoch 25: | Loss: 0.06914 | Dice: 0.934 | Time: 4.0
# Validation Epoch 25: | Loss: 0.24279 | Dice: 0.761 | Time: 0.4833
# Training Epoch 26: | Loss: 0.06088 | Dice: 0.942 | Time: 4.0
# Validation Epoch 26: | Loss: 0.22344 | Dice: 0.781 | Time: 0.3
# Training Epoch 27: | Loss: 0.06630 | Dice: 0.937 | Time: 4.1167
# Validation Epoch 27: | Loss: 0.23919 | Dice: 0.765 | Time: 0.3
# Training Epoch 28: | Loss: 0.05948 | Dice: 0.944 | Time: 4.1
# Validation Epoch 28: | Loss: 0.24336 | Dice: 0.761 | Time: 0.3667
# Training Epoch 29: | Loss: 0.06715 | Dice: 0.939 | Time: 3.95
# Validation Epoch 29: | Loss: 0.26264 | Dice: 0.742 | Time: 0.4167
# Training Epoch 30: | Loss: 0.07185 | Dice: 0.931 | Time: 3.9833
# Validation Epoch 30: | Loss: 0.22530 | Dice: 0.778 | Time: 0.4
# Training Epoch 31: | Loss: 0.04846 | Dice: 0.954 | Time: 3.9667
# Validation Epoch 31: | Loss: 0.24778 | Dice: 0.756 | Time: 0.3833
# Training Epoch 32: | Loss: 0.06617 | Dice: 0.937 | Time: 4.0167
# Validation Epoch 32: | Loss: 0.22848 | Dice: 0.775 | Time: 0.4167
# Training Epoch 33: | Loss: 0.05972 | Dice: 0.943 | Time: 4.0333
# Validation Epoch 33: | Loss: 0.22794 | Dice: 0.776 | Time: 0.2667
# Training Epoch 34: | Loss: 0.06668 | Dice: 0.936 | Time: 3.9667
# Validation Epoch 34: | Loss: 0.23117 | Dice: 0.773 | Time: 0.3833
# Training Epoch 35: | Loss: 0.06355 | Dice: 0.939 | Time: 3.85
# Validation Epoch 35: | Loss: 0.22156 | Dice: 0.783 | Time: 0.3667
# Training Epoch 36: | Loss: 0.06136 | Dice: 0.943 | Time: 3.9333
# Validation Epoch 36: | Loss: 0.23275 | Dice: 0.772 | Time: 0.2667
# Training Epoch 37: | Loss: 0.06919 | Dice: 0.936 | Time: 3.9667
# Validation Epoch 37: | Loss: 0.21676 | Dice: 0.788 | Time: 0.2667
# Training Epoch 38: | Loss: 0.05678 | Dice: 0.947 | Time: 4.0167
# Validation Epoch 38: | Loss: 0.13958 | Dice: 0.867 | Time: 0.2667
# Training Epoch 39: | Loss: 0.03659 | Dice: 0.968 | Time: 3.9833
# Validation Epoch 39: | Loss: 0.05247 | Dice: 0.960 | Time: 0.3833
# Training Epoch 40: | Loss: 0.02534 | Dice: 0.980 | Time: 3.9167
# Validation Epoch 40: | Loss: 0.11174 | Dice: 0.908 | Time: 0.4167
# Training Epoch 41: | Loss: 0.01974 | Dice: 0.985 | Time: 3.85
# Validation Epoch 41: | Loss: 0.03439 | Dice: 0.975 | Time: 0.2667
# Training Epoch 42: | Loss: 0.01416 | Dice: 0.990 | Time: 3.9667
# Validation Epoch 42: | Loss: 0.03740 | Dice: 0.977 | Time: 0.4333
# Training Epoch 43: | Loss: 0.01420 | Dice: 0.990 | Time: 3.8833
# Validation Epoch 43: | Loss: 0.10858 | Dice: 0.906 | Time: 0.3333
# Training Epoch 44: | Loss: 0.03100 | Dice: 0.977 | Time: 3.95
# Validation Epoch 44: | Loss: 0.03349 | Dice: 0.981 | Time: 0.4
# Training Epoch 45: | Loss: 0.01468 | Dice: 0.991 | Time: 3.85
# Validation Epoch 45: | Loss: 0.02869 | Dice: 0.985 | Time: 0.4
# Training Epoch 46: | Loss: 0.01028 | Dice: 0.993 | Time: 3.8
# Validation Epoch 46: | Loss: 0.02583 | Dice: 0.986 | Time: 0.3833
# Training Epoch 47: | Loss: 0.00982 | Dice: 0.993 | Time: 3.9333
# Validation Epoch 47: | Loss: 0.02295 | Dice: 0.987 | Time: 0.4
# Training Epoch 48: | Loss: 0.00946 | Dice: 0.994 | Time: 3.8833
# Validation Epoch 48: | Loss: 0.02691 | Dice: 0.985 | Time: 0.4167
# Training Epoch 49: | Loss: 0.00889 | Dice: 0.994 | Time: 3.9333
# Validation Epoch 49: | Loss: 0.01888 | Dice: 0.989 | Time: 0.4167
# Training Epoch 50: | Loss: 0.00848 | Dice: 0.994 | Time: 3.8167
# Validation Epoch 50: | Loss: 0.01835 | Dice: 0.990 | Time: 0.3833
# Training Epoch 51: | Loss: 0.00768 | Dice: 0.995 | Time: 3.9
# Validation Epoch 51: | Loss: 0.02960 | Dice: 0.982 | Time: 0.4167
# Training Epoch 52: | Loss: 0.01828 | Dice: 0.986 | Time: 3.85
# Validation Epoch 52: | Loss: 0.03331 | Dice: 0.981 | Time: 0.3833
# Training Epoch 53: | Loss: 0.01016 | Dice: 0.993 | Time: 3.95
# Validation Epoch 53: | Loss: 0.02254 | Dice: 0.990 | Time: 0.3667
# Training Epoch 54: | Loss: 0.00879 | Dice: 0.994 | Time: 3.95
# Validation Epoch 54: | Loss: 0.01766 | Dice: 0.991 | Time: 0.3333
# Training Epoch 55: | Loss: 0.00869 | Dice: 0.995 | Time: 4.0167
# Validation Epoch 55: | Loss: 0.02049 | Dice: 0.991 | Time: 0.4
# Training Epoch 56: | Loss: 0.00807 | Dice: 0.995 | Time: 3.8667
# Validation Epoch 56: | Loss: 0.01385 | Dice: 0.993 | Time: 0.4
# Training Epoch 57: | Loss: 0.00698 | Dice: 0.995 | Time: 3.9
# Validation Epoch 57: | Loss: 0.01375 | Dice: 0.993 | Time: 0.4333
# Training Epoch 58: | Loss: 0.02007 | Dice: 0.987 | Time: 3.8833
# Validation Epoch 58: | Loss: 0.18464 | Dice: 0.826 | Time: 0.3667
# Training Epoch 59: | Loss: 0.02348 | Dice: 0.984 | Time: 3.8833
# Validation Epoch 59: | Loss: 0.01784 | Dice: 0.991 | Time: 0.3667
# Training Epoch 60: | Loss: 0.01053 | Dice: 0.993 | Time: 3.9667
# Validation Epoch 60: | Loss: 0.01484 | Dice: 0.993 | Time: 0.4167
# Training Epoch 61: | Loss: 0.00800 | Dice: 0.995 | Time: 3.9333
# Validation Epoch 61: | Loss: 0.01746 | Dice: 0.992 | Time: 0.3833
# Training Epoch 62: | Loss: 0.00722 | Dice: 0.995 | Time: 3.8667
# Validation Epoch 62: | Loss: 0.01185 | Dice: 0.994 | Time: 0.4167
# Training Epoch 63: | Loss: 0.00759 | Dice: 0.995 | Time: 3.8667
# Validation Epoch 63: | Loss: 0.01420 | Dice: 0.994 | Time: 0.4167
# Training Epoch 64: | Loss: 0.02134 | Dice: 0.984 | Time: 3.9333
# Validation Epoch 64: | Loss: 0.03724 | Dice: 0.979 | Time: 0.2833
# Training Epoch 65: | Loss: 0.01122 | Dice: 0.993 | Time: 4.0
# Validation Epoch 65: | Loss: 0.01261 | Dice: 0.993 | Time: 0.4333
# Training Epoch 66: | Loss: 0.00715 | Dice: 0.995 | Time: 3.9
# Validation Epoch 66: | Loss: 0.01062 | Dice: 0.994 | Time: 0.45
# Training Epoch 67: | Loss: 0.00698 | Dice: 0.995 | Time: 3.7833
# Validation Epoch 67: | Loss: 0.01051 | Dice: 0.994 | Time: 0.3667
# Training Epoch 68: | Loss: 0.00670 | Dice: 0.996 | Time: 3.9667
# Validation Epoch 68: | Loss: 0.01001 | Dice: 0.994 | Time: 0.35
# Training Epoch 69: | Loss: 0.00674 | Dice: 0.996 | Time: 3.9333
# Validation Epoch 69: | Loss: 0.01247 | Dice: 0.994 | Time: 0.4
# Training Epoch 70: | Loss: 0.00758 | Dice: 0.995 | Time: 3.9833
# Validation Epoch 70: | Loss: 0.01692 | Dice: 0.992 | Time: 0.3167
# Training Epoch 71: | Loss: 0.00689 | Dice: 0.996 | Time: 3.9333
# Validation Epoch 71: | Loss: 0.00851 | Dice: 0.995 | Time: 0.3667
# Training Epoch 72: | Loss: 0.00652 | Dice: 0.996 | Time: 4.0
# Validation Epoch 72: | Loss: 0.00925 | Dice: 0.995 | Time: 0.4
# Training Epoch 73: | Loss: 0.00662 | Dice: 0.996 | Time: 3.95
# Validation Epoch 73: | Loss: 0.00800 | Dice: 0.996 | Time: 0.4
# Training Epoch 74: | Loss: 0.00804 | Dice: 0.994 | Time: 3.95
# Validation Epoch 74: | Loss: 0.01085 | Dice: 0.994 | Time: 0.4
# Training Epoch 75: | Loss: 0.03754 | Dice: 0.973 | Time: 3.9833
# Validation Epoch 75: | Loss: 0.01262 | Dice: 0.993 | Time: 0.4
# Training Epoch 76: | Loss: 0.00823 | Dice: 0.995 | Time: 3.9
# Validation Epoch 76: | Loss: 0.00963 | Dice: 0.995 | Time: 0.3333
# Training Epoch 77: | Loss: 0.00713 | Dice: 0.995 | Time: 4.0333
# Validation Epoch 77: | Loss: 0.00915 | Dice: 0.995 | Time: 0.3
# Training Epoch 78: | Loss: 0.00660 | Dice: 0.996 | Time: 3.9833
# Validation Epoch 78: | Loss: 0.00790 | Dice: 0.995 | Time: 0.3833
# Training Epoch 79: | Loss: 0.00633 | Dice: 0.996 | Time: 3.8667
# Validation Epoch 79: | Loss: 0.00772 | Dice: 0.996 | Time: 0.4333
# Training Epoch 80: | Loss: 0.00616 | Dice: 0.996 | Time: 3.8333
# Validation Epoch 80: | Loss: 0.00752 | Dice: 0.996 | Time: 0.4
# Training Epoch 81: | Loss: 0.00601 | Dice: 0.996 | Time: 3.8333
# Validation Epoch 81: | Loss: 0.00734 | Dice: 0.996 | Time: 0.4
# Training Epoch 82: | Loss: 0.00593 | Dice: 0.996 | Time: 3.9
# Validation Epoch 82: | Loss: 0.00724 | Dice: 0.996 | Time: 0.3833
# Training Epoch 83: | Loss: 0.00591 | Dice: 0.996 | Time: 3.8333
# Validation Epoch 83: | Loss: 0.00694 | Dice: 0.996 | Time: 0.3667
# Training Epoch 84: | Loss: 0.00597 | Dice: 0.996 | Time: 3.9833
# Validation Epoch 84: | Loss: 0.00686 | Dice: 0.996 | Time: 0.2833
# Training Epoch 85: | Loss: 0.00582 | Dice: 0.996 | Time: 4.0333
# Validation Epoch 85: | Loss: 0.00679 | Dice: 0.996 | Time: 0.3833
# Training Epoch 86: | Loss: 0.00594 | Dice: 0.996 | Time: 3.9
# Validation Epoch 86: | Loss: 0.00708 | Dice: 0.996 | Time: 0.3833
# Training Epoch 87: | Loss: 0.00588 | Dice: 0.996 | Time: 3.9833
# Validation Epoch 87: | Loss: 0.00691 | Dice: 0.996 | Time: 0.2667
# Training Epoch 88: | Loss: 0.00586 | Dice: 0.996 | Time: 3.9
# Validation Epoch 88: | Loss: 0.00667 | Dice: 0.996 | Time: 0.4333
# Training Epoch 89: | Loss: 0.02007 | Dice: 0.985 | Time: 3.9167
# Validation Epoch 89: | Loss: 0.18886 | Dice: 0.895 | Time: 0.4333
# Training Epoch 90: | Loss: 0.02281 | Dice: 0.984 | Time: 3.85
# Validation Epoch 90: | Loss: 0.01017 | Dice: 0.994 | Time: 0.3833
# Training Epoch 91: | Loss: 0.00690 | Dice: 0.995 | Time: 3.9167
# Validation Epoch 91: | Loss: 0.00787 | Dice: 0.995 | Time: 0.4
# Training Epoch 92: | Loss: 0.00620 | Dice: 0.996 | Time: 4.0333
# Validation Epoch 92: | Loss: 0.00712 | Dice: 0.996 | Time: 0.2667
# Training Epoch 93: | Loss: 0.00580 | Dice: 0.996 | Time: 4.0333
# Validation Epoch 93: | Loss: 0.00702 | Dice: 0.996 | Time: 0.4
# Training Epoch 94: | Loss: 0.00552 | Dice: 0.996 | Time: 3.8667
# Validation Epoch 94: | Loss: 0.00665 | Dice: 0.996 | Time: 0.3833
# Training Epoch 95: | Loss: 0.00538 | Dice: 0.996 | Time: 3.8833
# Validation Epoch 95: | Loss: 0.00641 | Dice: 0.996 | Time: 0.3667
# Training Epoch 96: | Loss: 0.00534 | Dice: 0.996 | Time: 3.9667
# Validation Epoch 96: | Loss: 0.00636 | Dice: 0.996 | Time: 0.4
# Training Epoch 97: | Loss: 0.00528 | Dice: 0.997 | Time: 3.9167
# Validation Epoch 97: | Loss: 0.00623 | Dice: 0.996 | Time: 0.3667
# Training Epoch 98: | Loss: 0.00529 | Dice: 0.997 | Time: 3.9667
# Validation Epoch 98: | Loss: 0.00633 | Dice: 0.996 | Time: 0.4333
# Training Epoch 99: | Loss: 0.00528 | Dice: 0.997 | Time: 3.9167
# Validation Epoch 99: | Loss: 0.00624 | Dice: 0.996 | Time: 0.4333
# Training Epoch 100: | Loss: 0.00539 | Dice: 0.996 | Time: 3.9
# Validation Epoch 100: | Loss: 0.00627 | Dice: 0.996 | Time: 0.4
# Training Epoch 101: | Loss: 0.00538 | Dice: 0.996 | Time: 3.9667
# Validation Epoch 101: | Loss: 0.00632 | Dice: 0.996 | Time: 0.35
# Training Epoch 102: | Loss: 0.00541 | Dice: 0.996 | Time: 4.0833
# Validation Epoch 102: | Loss: 0.00612 | Dice: 0.997 | Time: 0.3667
# Training Epoch 103: | Loss: 0.00533 | Dice: 0.997 | Time: 4.0833
# Validation Epoch 103: | Loss: 0.00656 | Dice: 0.996 | Time: 0.4
# Training Epoch 104: | Loss: 0.00544 | Dice: 0.996 | Time: 4.0667
# Validation Epoch 104: | Loss: 0.00619 | Dice: 0.996 | Time: 0.3833
# Training Epoch 105: | Loss: 0.00519 | Dice: 0.997 | Time: 3.9667
# Validation Epoch 105: | Loss: 0.00719 | Dice: 0.996 | Time: 0.4667
# Training Epoch 106: | Loss: 0.00521 | Dice: 0.997 | Time: 4.2833
# Validation Epoch 106: | Loss: 0.00652 | Dice: 0.997 | Time: 0.3167
# Training Epoch 107: | Loss: 0.00550 | Dice: 0.996 | Time: 3.6833
# Validation Epoch 107: | Loss: 0.00587 | Dice: 0.997 | Time: 0.2667
# Training Epoch 108: | Loss: 0.00502 | Dice: 0.997 | Time: 3.5833
# Validation Epoch 108: | Loss: 0.00629 | Dice: 0.996 | Time: 0.3833
# Training Epoch 109: | Loss: 0.00519 | Dice: 0.997 | Time: 3.7667
# Validation Epoch 109: | Loss: 0.00590 | Dice: 0.997 | Time: 0.2833
# Training Epoch 110: | Loss: 0.00495 | Dice: 0.997 | Time: 3.8833
# Validation Epoch 110: | Loss: 0.00588 | Dice: 0.997 | Time: 0.3333
# Training Epoch 111: | Loss: 0.00498 | Dice: 0.997 | Time: 4.0333
# Validation Epoch 111: | Loss: 0.00562 | Dice: 0.997 | Time: 0.3833
# Training Epoch 112: | Loss: 0.02757 | Dice: 0.977 | Time: 4.0333
# Validation Epoch 112: | Loss: 0.01066 | Dice: 0.993 | Time: 0.3167
# Training Epoch 113: | Loss: 0.00615 | Dice: 0.996 | Time: 3.9333
# Validation Epoch 113: | Loss: 0.00663 | Dice: 0.996 | Time: 0.4333
# Training Epoch 114: | Loss: 0.00522 | Dice: 0.997 | Time: 4.05
# Validation Epoch 114: | Loss: 0.00623 | Dice: 0.996 | Time: 0.45
# Training Epoch 115: | Loss: 0.00485 | Dice: 0.997 | Time: 4.2
# Validation Epoch 115: | Loss: 0.00610 | Dice: 0.997 | Time: 0.3667
# Training Epoch 116: | Loss: 0.00466 | Dice: 0.997 | Time: 4.3667
# Validation Epoch 116: | Loss: 0.00572 | Dice: 0.997 | Time: 0.3
# Training Epoch 117: | Loss: 0.00458 | Dice: 0.997 | Time: 4.3167
# Validation Epoch 117: | Loss: 0.00573 | Dice: 0.997 | Time: 0.4167
# Training Epoch 118: | Loss: 0.00453 | Dice: 0.997 | Time: 4.05
# Validation Epoch 118: | Loss: 0.00635 | Dice: 0.996 | Time: 0.2667
# Training Epoch 119: | Loss: 0.00457 | Dice: 0.997 | Time: 4.1667
# Validation Epoch 119: | Loss: 0.00587 | Dice: 0.997 | Time: 0.4167
# Training Epoch 120: | Loss: 0.00507 | Dice: 0.997 | Time: 4.6667
# Validation Epoch 120: | Loss: 0.00589 | Dice: 0.997 | Time: 0.6
# Training Epoch 121: | Loss: 0.00451 | Dice: 0.997 | Time: 10.6
# Validation Epoch 121: | Loss: 0.00574 | Dice: 0.997 | Time: 0.4667
# Training Epoch 122: | Loss: 0.00462 | Dice: 0.997 | Time: 4.6167
# Validation Epoch 122: | Loss: 0.00575 | Dice: 0.997 | Time: 0.4333
# Training Epoch 123: | Loss: 0.00464 | Dice: 0.997 | Time: 4.3167
# Validation Epoch 123: | Loss: 0.00584 | Dice: 0.997 | Time: 0.4
# Training Epoch 124: | Loss: 0.00451 | Dice: 0.997 | Time: 4.3167
# Validation Epoch 124: | Loss: 0.00567 | Dice: 0.997 | Time: 0.4
# Training Epoch 125: | Loss: 0.00454 | Dice: 0.997 | Time: 4.2167
# Validation Epoch 125: | Loss: 0.00577 | Dice: 0.997 | Time: 0.4
# Training Epoch 126: | Loss: 0.00479 | Dice: 0.997 | Time: 4.2667
# Validation Epoch 126: | Loss: 0.00564 | Dice: 0.997 | Time: 0.3667
# Training Epoch 127: | Loss: 0.00446 | Dice: 0.997 | Time: 4.15
# Validation Epoch 127: | Loss: 0.00599 | Dice: 0.997 | Time: 0.4
# Training Epoch 128: | Loss: 0.00451 | Dice: 0.997 | Time: 4.3
# Validation Epoch 128: | Loss: 0.00537 | Dice: 0.997 | Time: 0.3333
# Training Epoch 129: | Loss: 0.00436 | Dice: 0.997 | Time: 4.3167
# Validation Epoch 129: | Loss: 0.00572 | Dice: 0.997 | Time: 0.4333
# Training Epoch 130: | Loss: 0.00439 | Dice: 0.997 | Time: 4.4333
# Validation Epoch 130: | Loss: 0.00552 | Dice: 0.997 | Time: 0.4167
# Training Epoch 131: | Loss: 0.00422 | Dice: 0.997 | Time: 4.4167
# Validation Epoch 131: | Loss: 0.00549 | Dice: 0.997 | Time: 0.3667
# Training Epoch 132: | Loss: 0.00451 | Dice: 0.997 | Time: 4.4833
# Validation Epoch 132: | Loss: 0.00519 | Dice: 0.997 | Time: 0.4
# Training Epoch 133: | Loss: 0.00417 | Dice: 0.997 | Time: 4.4833
# Validation Epoch 133: | Loss: 0.00532 | Dice: 0.997 | Time: 0.35
# Training Epoch 134: | Loss: 0.00411 | Dice: 0.997 | Time: 5.4167
# Validation Epoch 134: | Loss: 0.00529 | Dice: 0.997 | Time: 0.5167
# Training Epoch 135: | Loss: 0.00406 | Dice: 0.997 | Time: 5.45
# Validation Epoch 135: | Loss: 0.00544 | Dice: 0.997 | Time: 0.3
# Training Epoch 136: | Loss: 0.00423 | Dice: 0.997 | Time: 4.2833
# Validation Epoch 136: | Loss: 0.00518 | Dice: 0.997 | Time: 0.2833
# Training Epoch 137: | Loss: 0.00408 | Dice: 0.997 | Time: 4.4333
# Validation Epoch 137: | Loss: 0.00540 | Dice: 0.997 | Time: 0.4167
# Training Epoch 138: | Loss: 0.02114 | Dice: 0.984 | Time: 4.5167
# Validation Epoch 138: | Loss: 0.01070 | Dice: 0.993 | Time: 0.2833
# Training Epoch 139: | Loss: 0.00491 | Dice: 0.997 | Time: 4.6667
# Validation Epoch 139: | Loss: 0.00583 | Dice: 0.997 | Time: 0.3833
# Training Epoch 140: | Loss: 0.00425 | Dice: 0.997 | Time: 4.4
# Validation Epoch 140: | Loss: 0.00549 | Dice: 0.997 | Time: 0.3
# Training Epoch 141: | Loss: 0.00401 | Dice: 0.997 | Time: 4.45
# Validation Epoch 141: | Loss: 0.00536 | Dice: 0.997 | Time: 0.4
# Training Epoch 142: | Loss: 0.00379 | Dice: 0.997 | Time: 4.45
# Validation Epoch 142: | Loss: 0.00522 | Dice: 0.997 | Time: 0.45
# Training Epoch 143: | Loss: 0.00372 | Dice: 0.998 | Time: 4.6
# Validation Epoch 143: | Loss: 0.00517 | Dice: 0.997 | Time: 0.3333
# Training Epoch 144: | Loss: 0.00369 | Dice: 0.998 | Time: 4.6667
# Validation Epoch 144: | Loss: 0.00679 | Dice: 0.996 | Time: 0.2667
# Training Epoch 145: | Loss: 0.00368 | Dice: 0.998 | Time: 4.6667
# Validation Epoch 145: | Loss: 0.00527 | Dice: 0.997 | Time: 0.4333
# Training Epoch 146: | Loss: 0.00377 | Dice: 0.998 | Time: 4.25
# Validation Epoch 146: | Loss: 0.00520 | Dice: 0.997 | Time: 0.4
# Training Epoch 147: | Loss: 0.01051 | Dice: 0.993 | Time: 4.2
# Validation Epoch 147: | Loss: 0.07741 | Dice: 0.937 | Time: 0.35
# Training Epoch 148: | Loss: 0.00549 | Dice: 0.996 | Time: 4.0167
# Validation Epoch 148: | Loss: 0.00576 | Dice: 0.997 | Time: 0.3167
# Training Epoch 149: | Loss: 0.00415 | Dice: 0.997 | Time: 3.95
# Validation Epoch 149: | Loss: 0.00537 | Dice: 0.997 | Time: 0.2667
# Training Epoch 150: | Loss: 0.00387 | Dice: 0.997 | Time: 3.95
# Validation Epoch 150: | Loss: 0.00533 | Dice: 0.997 | Time: 0.3833
# Training Epoch 151: | Loss: 0.00371 | Dice: 0.998 | Time: 4.1833
# Validation Epoch 151: | Loss: 0.00521 | Dice: 0.997 | Time: 0.2833
# Training Epoch 152: | Loss: 0.00363 | Dice: 0.998 | Time: 4.3
# Validation Epoch 152: | Loss: 0.00527 | Dice: 0.997 | Time: 0.4
# Training Epoch 153: | Loss: 0.00363 | Dice: 0.998 | Time: 4.4167
# Validation Epoch 153: | Loss: 0.00537 | Dice: 0.997 | Time: 0.3167
# Training Epoch 154: | Loss: 0.00362 | Dice: 0.998 | Time: 4.7667
# Validation Epoch 154: | Loss: 0.00509 | Dice: 0.997 | Time: 0.4667
# Training Epoch 155: | Loss: 0.00371 | Dice: 0.998 | Time: 5.0333
# Validation Epoch 155: | Loss: 0.00527 | Dice: 0.997 | Time: 0.4333
# Training Epoch 156: | Loss: 0.00376 | Dice: 0.998 | Time: 4.7333
# Validation Epoch 156: | Loss: 0.00512 | Dice: 0.997 | Time: 0.45
# Training Epoch 157: | Loss: 0.00370 | Dice: 0.998 | Time: 4.6333
# Validation Epoch 157: | Loss: 0.00514 | Dice: 0.997 | Time: 0.4
# Training Epoch 158: | Loss: 0.00374 | Dice: 0.998 | Time: 4.4667
# Validation Epoch 158: | Loss: 0.00526 | Dice: 0.997 | Time: 0.4333
# Training Epoch 159: | Loss: 0.00373 | Dice: 0.998 | Time: 4.2667
# Validation Epoch 159: | Loss: 0.00520 | Dice: 0.997 | Time: 0.2833
# Training Epoch 160: | Loss: 0.00367 | Dice: 0.998 | Time: 4.3167
# Validation Epoch 160: | Loss: 0.00526 | Dice: 0.997 | Time: 0.4667
# Training Epoch 161: | Loss: 0.00365 | Dice: 0.998 | Time: 6.5833
# Validation Epoch 161: | Loss: 0.00525 | Dice: 0.997 | Time: 0.3833
# Training Epoch 162: | Loss: 0.00371 | Dice: 0.998 | Time: 4.1833
# Validation Epoch 162: | Loss: 0.00517 | Dice: 0.997 | Time: 0.35
# Training Epoch 163: | Loss: 0.00357 | Dice: 0.998 | Time: 4.1667
# Validation Epoch 163: | Loss: 0.00515 | Dice: 0.997 | Time: 0.45
# Training Epoch 164: | Loss: 0.01336 | Dice: 0.991 | Time: 4.0333
# Validation Epoch 164: | Loss: 0.01030 | Dice: 0.995 | Time: 0.4167
# Training Epoch 165: | Loss: 0.00604 | Dice: 0.996 | Time: 3.9833
# Validation Epoch 165: | Loss: 0.00678 | Dice: 0.996 | Time: 0.4333
# Training Epoch 166: | Loss: 0.00468 | Dice: 0.997 | Time: 3.9833
# Validation Epoch 166: | Loss: 0.00596 | Dice: 0.997 | Time: 0.3667
# Training Epoch 167: | Loss: 0.00411 | Dice: 0.997 | Time: 4.0
# Validation Epoch 167: | Loss: 0.00566 | Dice: 0.997 | Time: 0.4167
# Training Epoch 168: | Loss: 0.00379 | Dice: 0.997 | Time: 3.9333
# Validation Epoch 168: | Loss: 0.00547 | Dice: 0.997 | Time: 0.3333
# Training Epoch 169: | Loss: 0.00363 | Dice: 0.998 | Time: 4.1667
# Validation Epoch 169: | Loss: 0.00523 | Dice: 0.997 | Time: 0.4333
# Training Epoch 170: | Loss: 0.00340 | Dice: 0.998 | Time: 3.9167
# Validation Epoch 170: | Loss: 0.00505 | Dice: 0.997 | Time: 0.3833
# Training Epoch 171: | Loss: 0.00331 | Dice: 0.998 | Time: 4.1
# Validation Epoch 171: | Loss: 0.00511 | Dice: 0.997 | Time: 0.4167
# Training Epoch 172: | Loss: 0.00322 | Dice: 0.998 | Time: 4.05
# Validation Epoch 172: | Loss: 0.00511 | Dice: 0.997 | Time: 0.4
# Training Epoch 173: | Loss: 0.00321 | Dice: 0.998 | Time: 4.0667
# Validation Epoch 173: | Loss: 0.00508 | Dice: 0.997 | Time: 0.3833
# Training Epoch 174: | Loss: 0.00326 | Dice: 0.998 | Time: 4.1
# Validation Epoch 174: | Loss: 0.00506 | Dice: 0.997 | Time: 0.4
# Training Epoch 175: | Loss: 0.00331 | Dice: 0.998 | Time: 4.2
# Validation Epoch 175: | Loss: 0.00517 | Dice: 0.997 | Time: 0.4
# Training Epoch 176: | Loss: 0.00331 | Dice: 0.998 | Time: 4.1333
# Validation Epoch 176: | Loss: 0.00501 | Dice: 0.997 | Time: 0.3
# Training Epoch 177: | Loss: 0.00340 | Dice: 0.998 | Time: 4.2
# Validation Epoch 177: | Loss: 0.00517 | Dice: 0.997 | Time: 0.4167
# Training Epoch 178: | Loss: 0.00334 | Dice: 0.998 | Time: 4.2
# Validation Epoch 178: | Loss: 0.00522 | Dice: 0.997 | Time: 0.2833
# Training Epoch 179: | Loss: 0.00338 | Dice: 0.998 | Time: 4.3667
# Validation Epoch 179: | Loss: 0.00521 | Dice: 0.997 | Time: 0.2667
# Training Epoch 180: | Loss: 0.00352 | Dice: 0.998 | Time: 4.3167
# Validation Epoch 180: | Loss: 0.00931 | Dice: 0.995 | Time: 0.4
# Training Epoch 181: | Loss: 0.00474 | Dice: 0.997 | Time: 4.1667
# Validation Epoch 181: | Loss: 0.00520 | Dice: 0.997 | Time: 0.4167
# Training Epoch 182: | Loss: 0.00321 | Dice: 0.998 | Time: 4.2833
# Validation Epoch 182: | Loss: 0.00496 | Dice: 0.997 | Time: 0.4333
# Training Epoch 183: | Loss: 0.00320 | Dice: 0.998 | Time: 4.2833
# Validation Epoch 183: | Loss: 0.00498 | Dice: 0.997 | Time: 0.3167
# Training Epoch 184: | Loss: 0.00316 | Dice: 0.998 | Time: 4.3167
# Validation Epoch 184: | Loss: 0.00509 | Dice: 0.997 | Time: 0.3833
# Training Epoch 185: | Loss: 0.00317 | Dice: 0.998 | Time: 4.3167
# Validation Epoch 185: | Loss: 0.00504 | Dice: 0.997 | Time: 0.4
# Training Epoch 186: | Loss: 0.00325 | Dice: 0.998 | Time: 4.1833
# Validation Epoch 186: | Loss: 0.00513 | Dice: 0.997 | Time: 0.4333
# Training Epoch 187: | Loss: 0.00331 | Dice: 0.998 | Time: 4.2667
# Validation Epoch 187: | Loss: 0.00496 | Dice: 0.997 | Time: 0.3
# Training Epoch 188: | Loss: 0.00323 | Dice: 0.998 | Time: 4.3833
# Validation Epoch 188: | Loss: 0.00520 | Dice: 0.997 | Time: 0.4167
# Training Epoch 189: | Loss: 0.00321 | Dice: 0.998 | Time: 4.15
# Validation Epoch 189: | Loss: 0.00527 | Dice: 0.997 | Time: 0.4333
# Training Epoch 190: | Loss: 0.00325 | Dice: 0.998 | Time: 4.1833
# Validation Epoch 190: | Loss: 0.00514 | Dice: 0.997 | Time: 0.4
# Training Epoch 191: | Loss: 0.00314 | Dice: 0.998 | Time: 4.15
# Validation Epoch 191: | Loss: 0.00495 | Dice: 0.997 | Time: 0.3833
# Early stop, best dice coefficient: 0.9974150355709227%
# Total time : 862

# %% [markdown]
# # Saving and visualization

# %%
def train_vis(training_stats):

    ### Plotting Results
    train_logs = training_stats['train logs']
    val_logs = training_stats['validation logs']
    epochs = training_stats['current epoch'] + 1
    best_epoch = training_stats['best epoch'] 

#Loss
    plt.figure(figsize=(15, 6))
    
    plt.title("Loss",color='black')
    plt.plot(np.arange(1, epochs), train_logs["loss"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["loss"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch,color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Loss", color = 'black')
    plt.show()

# dice coefficient
    plt.figure(figsize=(15, 6))
    plt.title("Dice", color='black')
    plt.plot(np.arange(1, epochs), train_logs["dice coefficient"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["dice coefficient"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch, color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Accuracy", color='black')
    plt.show()

# %%
train_vis(training_stats)

# %%
# Saving the best model
def save_model(model, model_name, training_stats, parameters, img_lists):
    ''' Save model either for inference or for continuing training '''
    torch.save({'model_name': model_name,
                'model_state_dict': model.state_dict(),
                'parameters': (resize_size, n_channels, num_categories)
                }, f'{project_name}_{model_name}_inference.pt')
        
    torch.save({'model_name': model_name,
                'model_state_dict': model.state_dict(),
                'model_stats': training_stats,
                'parameters': (resize_size, n_channels, num_categories),
                'img_lists': img_lists
                }, f'{project_name}_{model_name}.pt')
    mylogs.info("Model saved")

# %%
img_lists = (train_img_mask_pairs, val_img_mask_pairs, test_img_mask_pairs)
save_model(model, model_name, training_stats, (resize_size, n_channels,num_categories),  img_lists)
# Out:
# Model saved

# %%
# Testing on a random test image 
def model_inference_preview(test_data_loader, label_values):
    for image,_ , actual_mask in test_data_loader:
        image.to('cpu')
        actual_mask.to('cpu')
        model.to('cpu')
        prediction_mask = model(image)
        prediction_mask = prediction_mask.permute(0,2,3,1)
   
        #### actual mask
        _, actual_masked_image = apply_color_masks(image, actual_mask,label_values)
        
        actual_masked_image = torch.from_numpy(actual_masked_image)
        actual_masked_image = actual_masked_image.squeeze()
        
        #### predicted mask
        _, predicted_masked_image = apply_color_masks(image, prediction_mask.detach(), label_values)
        predicted_masked_image = torch.from_numpy(predicted_masked_image)
        predicted_masked_image = predicted_masked_image.squeeze()
        
        imgs = [actual_masked_image, predicted_masked_image]
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        n_row = 1
        n_col = 2
        _, axs = plt.subplots(n_row, n_col, figsize=(18, 18))
        axs = axs.flatten()
        titles = [' Actual Mask', 'Predicted Mask']
        for title, img, ax in zip(titles, imgs, axs):
            ax.imshow(make_grid(img, 4))
            ax.set_title(title)
        plt.show()
        
        #saving
        break

model_inference_preview(test_data_loader,label_values)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
