# %%
import os
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as tv
from torchvision.utils import make_grid
from sklearn.model_selection import train_test_split
from PIL import Image
import logging
import matplotlib.pyplot as plt
import copy
import pandas as pd
# %matplotlib inline

# %%
mylogs = logging.getLogger()
mylogs.setLevel(logging.INFO)
# Logging to file
file = logging.FileHandler("training.log", mode='w')
file.setLevel(logging.INFO)
fileformat = logging.Formatter("%(asctime)s:%(levelname)s:%(message)s",datefmt="%H:%M:%S")
file.setFormatter(fileformat)
mylogs.addHandler(file)
# Logging to console
stream = logging.StreamHandler()
stream.setLevel(logging.INFO)
mylogs.addHandler(stream)

# %% [markdown]
# # Paths and parameters

# %%
test_mask_dir = None
train_img_dir= r"E:/ct_multi_segmentation/train/images/"
train_mask_dir =  r"E:/ct_multi_segmentation/train/masks/"
test_img_dir = r"E:/ct_multi_segmentation/test/images/"
test_mask_dir = r"E:/ct_multi_segmentation/test/masks/"
model_name = 'Unet'
project_name = "CT_multi_class_segmentation"
resize_size = (224, 224)
label_values = (32768, 32769, 32770, 32771, 32773)
num_categories = len(label_values)
n_channels = 1

# %% [markdown]
# # Creating list of images and masks

# %%
def create_img_list(img_folder):
    img_list = []
    for (dirpath, dirnames, filenames) in os.walk(img_folder):
        img_list += [os.path.join(dirpath, file) for file in filenames]
    return img_list

# %%
train_img_list = create_img_list(train_img_dir)
test_img_list = create_img_list(test_img_dir)

if train_mask_dir:
    train_mask_img_list = create_img_list(train_mask_dir)
if test_mask_dir:
    test_mask_img_list = create_img_list(test_mask_dir)

# %%
def make_img_mask_pairs(img_list, mask_list):
    img_path_names =  {os.path.basename(n):n for n in img_list}
    mask_path_names =  {os.path.basename(n):n for n in mask_list}
    img_mask_pairs = {}
    for name, path in img_path_names.items():
        if name in mask_path_names.keys():
            img_mask_pairs[path] = mask_path_names[name]
    return(img_mask_pairs)

# %%
train_img_mask_pairs = make_img_mask_pairs(train_img_list,train_mask_img_list)

# %%
test_img_mask_pairs = make_img_mask_pairs(test_img_list,test_mask_img_list)

# %%
def train_val_split(img_dic, split_ratio):
    val_dic = {}
    train_dic = {}
    for i in range(int(len(img_dic)*split_ratio)):
        random_entry = random.choice(list(img_dic.keys()))
        val_dic[random_entry] = img_dic[random_entry]    
    for key in img_dic.keys():
        if key not in val_dic.keys():
            train_dic[key] = img_dic[key]
    return(train_dic, val_dic)

# %%
train_img_mask_pairs, val_img_mask_pairs = train_val_split(train_img_mask_pairs, 0.2)

# %% [markdown]
# # Image Loading functions

# %%
def get_img_transform():
    return tv.Compose([
        tv.ToTensor(),
        tv.Normalize((0), (1)),
    ])
def get_mask_transform():
    return tv.Compose([
        tv.ToTensor(),
    ])
transforms = (get_img_transform(),get_mask_transform())

# %%
class loadDataset(Dataset):
    def __init__(self,img_mask_pairs_dic, transforms, label_values):
        super().__init__()
        self.imgs = list(img_mask_pairs_dic.keys())
        self.masks = list(img_mask_pairs_dic.values())
        self.img_transform = transforms[0]
        self.mask_transform = transforms[1]
        self.label_values = label_values
        
    def __getitem__(self, idx):
        image_path = self.imgs[idx]
        mask_path = self.masks[idx]
      ### Reading, converting and normalizing image
        ### Reading, converting and normalizing image
        img = Image.open(image_path)
        img = img.resize((resize_size[0], resize_size[1]))
        ### Doing the same for mask
        mask = Image.open(mask_path)
        mask = mask.resize((resize_size[0], resize_size[1]))
        mask = np.asarray(mask)
        # one hode encode mask
        # from https://github.com/cm-amaya/UNet_Multiclass/blob/master/data_loader.py
        masks = [(mask == v) for v in self.label_values]

        mask = np.stack(masks, axis=-1).astype('bool')
        ### Apply Transforms on image
        img = self.img_transform(img)
            # creating mask tensor as a label
        transformed_mask  = self.mask_transform(mask)
        return img.float(), transformed_mask.float(), mask

    def __len__(self):
        return len(self.imgs)

# %%
train_dataset = loadDataset(train_img_mask_pairs, transforms, label_values)
val_dataset = loadDataset(val_img_mask_pairs, transforms, label_values)
test_dataset = loadDataset(test_img_mask_pairs, transforms, label_values)

# %%
train_data_loader = DataLoader(
    dataset = train_dataset,
    num_workers = 0,
    batch_size = 4,
    shuffle = True
)
val_data_loader = DataLoader(
    dataset = val_dataset,
    num_workers = 0,
    batch_size = 2,
    shuffle = True
)
test_data_loader = DataLoader(
    dataset = test_dataset,
    num_workers = 0,
    batch_size = 1,
    shuffle = True
)

# %%
def apply_color_masks(image, mask, num_categories):
    color_to_categories = ((0,0,100), (0,100,0), (100,0,0), (100,100,0), (100,0,100), 
                           (0,100,100), (100,100,100))
    image = image.numpy()
    mask = mask.numpy()
    image = image.squeeze()
    mask = mask.squeeze()
    mask = np.argmax(mask, axis=2)
    
    image = np.stack((image,)*3, axis=-1)
    mask = np.stack((mask,)*3, axis=-1)
    
    masked_image = copy.deepcopy(image)
    

    # select category channel
    for category in range(len(num_categories)):
        if category:
            masked_image[:,:,0][mask[:,:,0]==category] = color_to_categories[category][0]
            masked_image[:,:,1][mask[:,:,0]==category] = color_to_categories[category][1]
            masked_image[:,:,2][mask[:,:,0]==category] = color_to_categories[category][2]

    return image, masked_image

# %%
  def dataset_preview(train_data_loader, num_categories):
    for image, _, mask in train_data_loader:
        # Selecting a chanel for a mask
        image, masked_image = apply_color_masks(image, mask, num_categories)
        image = torch.from_numpy(image)
        masked_image = torch.from_numpy(masked_image)
 
        imgs = [image, masked_image]
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        n_row = 1
        n_col = 2
        _, axs = plt.subplots(n_row, n_col, figsize=(18, 18))
        axs = axs.flatten()
        titles = [' Image', 'Image with mask']
        for title, img, ax in zip(titles, imgs, axs):
            ax.imshow(make_grid(img, 4))
            ax.set_title(title)
        plt.show()
        break
        
dataset_preview(test_data_loader,label_values)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Functions for training

# %%
# https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_model.py
from UNet import UNet
model = UNet(n_channels, num_categories)

# %%
#from https://www.kaggle.com/bigironsphere/loss-function-library-keras-pytorch
class DiceBCELoss(nn.Module):
    # Return Dice and Dice loss
    def __init__(self, weight=None, size_average=True):
        super(DiceBCELoss, self).__init__()

    def forward(self, inputs, targets, smooth=1):
        #comment out if your model contains a sigmoid or equivalent activation layer
        inputs = torch.sigmoid(inputs)       
        
        #flatten label and prediction tensors
        inputs = inputs.view(-1)
        targets = targets.view(-1)
        
        intersection = (inputs * targets).sum()
        dice_coefficient =  (2. * intersection + smooth) / (torch.sum(targets) + torch.sum(inputs) + smooth)
        
        dice_loss = 1 - (2.*intersection + smooth)/(inputs.sum() + targets.sum() + smooth)  
        BCE = F.binary_cross_entropy(inputs, targets, reduction='mean')
        Dice_BCE = BCE + dice_loss
        
        return Dice_BCE, dice_coefficient

# %%
class Optimizer:
    def __init__(self, model):
        self.optimizer_dict = {}
        self.optimizer_dict['optimizer'] = torch.optim.Adam(model.parameters(), lr = 0.0001)
        self.optimizer_dict['lr_scheduler'] = torch.optim.lr_scheduler.StepLR(self.optimizer_dict['optimizer'], step_size = 5, gamma = 0.5)
        self.optimizer_dict['criterion'] = DiceBCELoss(nn.Module)

    def return_state_dict(self):
        return self.optimizer_dict['optimizer'].state_dict()

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
optimizerA = Optimizer(model)

# %%
mylogs.info("Model: " + model_name )
# Loading model to device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
mylogs.info(f"Device is: {str(device)}")
model.to(device)
optimizerA = Optimizer(model)
# Out:
# Model: Unet
# Device is: cuda

# %%
def train_one_epoch(data_loader, optimizer_obj, phase):
    ## global to local
    optimizer = optimizer_obj.optimizer_dict['optimizer']
    criterion = optimizer_obj.optimizer_dict['criterion']
    lr_scheduler = optimizer_obj.optimizer_dict['criterion'] 
    ### Local Parameters
    epoch_loss = []
    epoch_dice = []
    start_time = time.time()
    
    ###Iterating over data loader
    for images, labels, _ in data_loader:
        #Loading images and labels to device
        images = images.to(device)
        labels = labels.to(device)
        #Reseting Gradients
        optimizer.zero_grad()
        #Forward
        preds = model(images)
        #Calculating Loss
        _loss, dice_coefficient = criterion(preds, labels)
        loss = _loss.item()
        epoch_loss.append(float(loss))
        epoch_dice.append(float(dice_coefficient))
        #Backward if train phase
        if phase == "train":
            _loss.backward()
            optimizer.step()
    ###Overall Epoch Results
    end_time = time.time()
    total_time = int(end_time - start_time)/60
    ###Dice coefficient and Loss
    epoch_loss = np.mean(epoch_loss)
    epoch_dice = np.mean(epoch_dice)
    ###Storing results to logs
    return epoch_loss, epoch_dice, total_time

# %%
def report_in_progress(phase, epoch, loss, dice, _time):
       #Print epoch details
        mylogs.info(f'{"Training" if phase == False else "Validation"} Epoch {epoch}: | Loss: {loss:.5f} | Dice: {dice:.3f} | Time: {(round(_time, 4))}')

# %%
def train_model(model, optimizer_obj, max_n_epochs, early_stop_epoch_thresh = 20):
    start_time = time.time()
    # initializing  training stats
    train_logs =  {"loss" : [], "dice coefficient" : [], "time" : []}
    val_logs = {"loss" : [], "dice coefficient" : [], "time" : []} 
    mylogs.info("Training started")
    best_model = model
    best_epoch = 1
    best_val_dice = 0
    bad_dice_epoch = 0
    current_epoch = 0
    best_train_logs = {}
    best_val_logs = {}
    best_model_optimizer_state_dict = optimizer_obj.return_state_dict()
    for epoch in range(1, max_n_epochs + 1):
        if bad_dice_epoch < early_stop_epoch_thresh:
            current_epoch = epoch 
            ###Training
            train_loss, train_dice, train_time = train_one_epoch(train_data_loader, optimizer_obj, "train")
            #Print train Epoch Details      
            report_in_progress(0, epoch, train_loss, train_dice, train_time)
            #Adding stats for the epoch
            train_logs["loss"].append(train_loss)
            train_logs["dice coefficient"].append(train_dice)
            train_logs["time"].append(train_time)
            ###Validation
            val_loss, val_dice, val_time = train_one_epoch(val_data_loader, optimizer_obj, "validation")
            #Print Val Epoch  Details
            report_in_progress(1, epoch, val_loss, val_dice, val_time)
            #adding stats on the epoch
            val_logs["loss"].append(val_loss)
            val_logs["dice coefficient"].append(val_dice)
            val_logs["time"].append(val_time)
            # Early stop processing
            if val_dice > best_val_dice:
                best_val_dice = val_dice
                best_model = copy.deepcopy(model)
                bad_dice_epoch = 0
                best_train_logs = train_logs
                best_val_logs = val_logs
                best_epoch = epoch 
            else:
                bad_dice_epoch +=1
        else:
            mylogs.info(f"Early stop, best dice coefficient: {best_val_dice}%")
            break
    end_time = time.time()
    total_time = end_time - start_time
    mylogs.info(f"Total time : {int(total_time/60)}")
    # packing training data into a dictionary
    training_stats = {}
    training_stats['train logs'] = train_logs
    training_stats['validation logs'] = val_logs
    training_stats['best train logs'] = best_train_logs
    training_stats['best validation logs'] = best_val_logs
    training_stats['best validation dice'] = best_val_dice
    training_stats['best epoch'] = best_epoch
    training_stats['current epoch'] = current_epoch 
    
    return best_model, best_model_optimizer_state_dict, training_stats

# %%
# Training de novo
n_of_epochs = 100
model, model_optimizer_state_dict,  training_stats = train_model(model, optimizerA, n_of_epochs)
# Out:
# Training started
# Training Epoch 1: | Loss: 0.97997 | Dice: 0.363 | Time: 3.2167
# Validation Epoch 1: | Loss: 0.78343 | Dice: 0.455 | Time: 0.55
# Training Epoch 2: | Loss: 0.45600 | Dice: 0.659 | Time: 4.4667
# Validation Epoch 2: | Loss: 0.46458 | Dice: 0.659 | Time: 0.4667
# Training Epoch 3: | Loss: 0.22928 | Dice: 0.824 | Time: 5.15
# Validation Epoch 3: | Loss: 0.38409 | Dice: 0.715 | Time: 0.3667
# Training Epoch 4: | Loss: 0.16520 | Dice: 0.873 | Time: 5.4167
# Validation Epoch 4: | Loss: 0.32779 | Dice: 0.738 | Time: 0.4833
# Training Epoch 5: | Loss: 0.12739 | Dice: 0.899 | Time: 5.6333
# Validation Epoch 5: | Loss: 0.28232 | Dice: 0.770 | Time: 0.5
# Training Epoch 6: | Loss: 0.10291 | Dice: 0.917 | Time: 5.5
# Validation Epoch 6: | Loss: 0.29332 | Dice: 0.751 | Time: 0.4833
# Training Epoch 7: | Loss: 0.09802 | Dice: 0.918 | Time: 5.5
# Validation Epoch 7: | Loss: 0.25796 | Dice: 0.775 | Time: 0.4833
# Training Epoch 8: | Loss: 0.09017 | Dice: 0.922 | Time: 5.4833
# Validation Epoch 8: | Loss: 0.26700 | Dice: 0.767 | Time: 0.35
# Training Epoch 9: | Loss: 0.09949 | Dice: 0.923 | Time: 5.7833
# Validation Epoch 9: | Loss: 0.28347 | Dice: 0.762 | Time: 0.5167
# Training Epoch 10: | Loss: 0.07438 | Dice: 0.936 | Time: 5.45
# Validation Epoch 10: | Loss: 0.23569 | Dice: 0.787 | Time: 0.4833
# Training Epoch 11: | Loss: 0.07056 | Dice: 0.939 | Time: 5.4
# Validation Epoch 11: | Loss: 0.26076 | Dice: 0.774 | Time: 0.4833
# Training Epoch 12: | Loss: 0.07679 | Dice: 0.937 | Time: 5.4833
# Validation Epoch 12: | Loss: 0.24099 | Dice: 0.784 | Time: 0.4833
# Training Epoch 13: | Loss: 0.06574 | Dice: 0.942 | Time: 5.45
# Validation Epoch 13: | Loss: 0.24970 | Dice: 0.781 | Time: 0.4833
# Training Epoch 14: | Loss: 0.07176 | Dice: 0.937 | Time: 5.45
# Validation Epoch 14: | Loss: 0.22658 | Dice: 0.795 | Time: 0.4833
# Training Epoch 15: | Loss: 0.08205 | Dice: 0.933 | Time: 5.5833
# Validation Epoch 15: | Loss: 0.23270 | Dice: 0.800 | Time: 0.4667
# Training Epoch 16: | Loss: 0.07707 | Dice: 0.930 | Time: 5.5167
# Validation Epoch 16: | Loss: 0.22104 | Dice: 0.793 | Time: 0.4833
# Training Epoch 17: | Loss: 0.07597 | Dice: 0.929 | Time: 5.45
# Validation Epoch 17: | Loss: 0.22235 | Dice: 0.788 | Time: 0.5
# Training Epoch 18: | Loss: 0.06105 | Dice: 0.945 | Time: 5.4
# Validation Epoch 18: | Loss: 0.42878 | Dice: 0.726 | Time: 0.45
# Training Epoch 19: | Loss: 0.06803 | Dice: 0.939 | Time: 5.6667
# Validation Epoch 19: | Loss: 0.23460 | Dice: 0.773 | Time: 0.3667
# Training Epoch 20: | Loss: 0.05671 | Dice: 0.947 | Time: 5.5667
# Validation Epoch 20: | Loss: 0.21568 | Dice: 0.790 | Time: 0.4833
# Training Epoch 21: | Loss: 0.05520 | Dice: 0.948 | Time: 5.6333
# Validation Epoch 21: | Loss: 0.20511 | Dice: 0.802 | Time: 0.4667
# Training Epoch 22: | Loss: 0.06861 | Dice: 0.935 | Time: 5.4
# Validation Epoch 22: | Loss: 0.21500 | Dice: 0.790 | Time: 0.4833
# Training Epoch 23: | Loss: 0.07532 | Dice: 0.935 | Time: 5.35
# Validation Epoch 23: | Loss: 0.21080 | Dice: 0.796 | Time: 0.4667
# Training Epoch 24: | Loss: 0.05178 | Dice: 0.952 | Time: 5.6333
# Validation Epoch 24: | Loss: 0.23765 | Dice: 0.768 | Time: 0.4833
# Training Epoch 25: | Loss: 0.07275 | Dice: 0.930 | Time: 5.5667
# Validation Epoch 25: | Loss: 0.21795 | Dice: 0.791 | Time: 0.5167
# Training Epoch 26: | Loss: 0.04233 | Dice: 0.961 | Time: 5.7
# Validation Epoch 26: | Loss: 0.20827 | Dice: 0.797 | Time: 0.4833
# Training Epoch 27: | Loss: 0.06103 | Dice: 0.942 | Time: 5.4667
# Validation Epoch 27: | Loss: 0.20540 | Dice: 0.801 | Time: 0.5
# Training Epoch 28: | Loss: 0.07148 | Dice: 0.938 | Time: 5.6333
# Validation Epoch 28: | Loss: 0.23172 | Dice: 0.774 | Time: 0.3833
# Training Epoch 29: | Loss: 0.06153 | Dice: 0.942 | Time: 5.6833
# Validation Epoch 29: | Loss: 0.20352 | Dice: 0.801 | Time: 0.5
# Training Epoch 30: | Loss: 0.06622 | Dice: 0.937 | Time: 5.4667
# Validation Epoch 30: | Loss: 0.23462 | Dice: 0.769 | Time: 0.4667
# Training Epoch 31: | Loss: 0.07051 | Dice: 0.932 | Time: 5.75
# Validation Epoch 31: | Loss: 0.23160 | Dice: 0.772 | Time: 0.5
# Training Epoch 32: | Loss: 0.06294 | Dice: 0.940 | Time: 5.85
# Validation Epoch 32: | Loss: 0.24076 | Dice: 0.763 | Time: 0.5167
# Training Epoch 33: | Loss: 0.07509 | Dice: 0.932 | Time: 5.7667
# Validation Epoch 33: | Loss: 0.20987 | Dice: 0.794 | Time: 0.5333
# Training Epoch 34: | Loss: 0.07508 | Dice: 0.928 | Time: 5.6667
# Validation Epoch 34: | Loss: 0.21170 | Dice: 0.792 | Time: 0.4833
# Training Epoch 35: | Loss: 0.07834 | Dice: 0.924 | Time: 5.7333
# Validation Epoch 35: | Loss: 0.20144 | Dice: 0.802 | Time: 0.4833
# Training Epoch 36: | Loss: 0.05945 | Dice: 0.943 | Time: 5.6833
# Validation Epoch 36: | Loss: 0.21806 | Dice: 0.786 | Time: 0.5167
# Training Epoch 37: | Loss: 0.07119 | Dice: 0.932 | Time: 6.0167
# Validation Epoch 37: | Loss: 0.22662 | Dice: 0.777 | Time: 0.4333
# Training Epoch 38: | Loss: 0.05910 | Dice: 0.946 | Time: 6.8
# Validation Epoch 38: | Loss: 0.20628 | Dice: 0.799 | Time: 0.5333
# Training Epoch 39: | Loss: 0.05894 | Dice: 0.944 | Time: 6.5667
# Validation Epoch 39: | Loss: 0.19493 | Dice: 0.810 | Time: 0.5167
# Training Epoch 40: | Loss: 0.05751 | Dice: 0.946 | Time: 6.6167
# Validation Epoch 40: | Loss: 0.15131 | Dice: 0.855 | Time: 0.55
# Training Epoch 41: | Loss: 0.05883 | Dice: 0.947 | Time: 6.6167
# Validation Epoch 41: | Loss: 0.07086 | Dice: 0.938 | Time: 0.5667
# Training Epoch 42: | Loss: 0.04406 | Dice: 0.960 | Time: 6.5167
# Validation Epoch 42: | Loss: 0.07054 | Dice: 0.940 | Time: 0.5333
# Training Epoch 43: | Loss: 0.02008 | Dice: 0.984 | Time: 6.4167
# Validation Epoch 43: | Loss: 0.18441 | Dice: 0.831 | Time: 0.4833
# Training Epoch 44: | Loss: 0.03114 | Dice: 0.974 | Time: 6.3833
# Validation Epoch 44: | Loss: 0.04115 | Dice: 0.969 | Time: 0.5
# Training Epoch 45: | Loss: 0.01450 | Dice: 0.989 | Time: 6.55
# Validation Epoch 45: | Loss: 0.03377 | Dice: 0.976 | Time: 0.5
# Training Epoch 46: | Loss: 0.01205 | Dice: 0.991 | Time: 6.25
# Validation Epoch 46: | Loss: 0.03549 | Dice: 0.980 | Time: 0.5167
# Training Epoch 47: | Loss: 0.01185 | Dice: 0.992 | Time: 6.5167
# Validation Epoch 47: | Loss: 0.03042 | Dice: 0.980 | Time: 0.5833
# Training Epoch 48: | Loss: 0.02795 | Dice: 0.980 | Time: 6.5167
# Validation Epoch 48: | Loss: 0.02934 | Dice: 0.984 | Time: 0.4667
# Training Epoch 49: | Loss: 0.01001 | Dice: 0.993 | Time: 6.7167
# Validation Epoch 49: | Loss: 0.02676 | Dice: 0.983 | Time: 0.5667
# Training Epoch 50: | Loss: 0.00933 | Dice: 0.994 | Time: 6.0333
# Validation Epoch 50: | Loss: 0.02238 | Dice: 0.987 | Time: 0.4833
# Training Epoch 51: | Loss: 0.00973 | Dice: 0.994 | Time: 6.3333
# Validation Epoch 51: | Loss: 0.02917 | Dice: 0.984 | Time: 0.5167
# Training Epoch 52: | Loss: 0.00970 | Dice: 0.994 | Time: 6.3
# Validation Epoch 52: | Loss: 0.02419 | Dice: 0.985 | Time: 0.4833
# Training Epoch 53: | Loss: 0.00865 | Dice: 0.994 | Time: 6.1833
# Validation Epoch 53: | Loss: 0.02060 | Dice: 0.987 | Time: 0.5167
# Training Epoch 54: | Loss: 0.00793 | Dice: 0.995 | Time: 6.3833
# Validation Epoch 54: | Loss: 0.02660 | Dice: 0.982 | Time: 0.5167
# Training Epoch 55: | Loss: 0.00785 | Dice: 0.995 | Time: 6.15
# Validation Epoch 55: | Loss: 0.02368 | Dice: 0.983 | Time: 0.3833
# Training Epoch 56: | Loss: 0.01869 | Dice: 0.988 | Time: 6.1667
# Validation Epoch 56: | Loss: 0.14491 | Dice: 0.888 | Time: 0.5167
# Training Epoch 57: | Loss: 0.03081 | Dice: 0.978 | Time: 5.8167
# Validation Epoch 57: | Loss: 0.02634 | Dice: 0.989 | Time: 0.5
# Training Epoch 58: | Loss: 0.00919 | Dice: 0.994 | Time: 5.9667
# Validation Epoch 58: | Loss: 0.02606 | Dice: 0.982 | Time: 0.45
# Training Epoch 59: | Loss: 0.00807 | Dice: 0.995 | Time: 6.05
# Validation Epoch 59: | Loss: 0.01958 | Dice: 0.988 | Time: 0.5
# Training Epoch 60: | Loss: 0.00776 | Dice: 0.995 | Time: 5.7333
# Validation Epoch 60: | Loss: 0.02376 | Dice: 0.984 | Time: 0.5
# Training Epoch 61: | Loss: 0.00714 | Dice: 0.995 | Time: 5.85
# Validation Epoch 61: | Loss: 0.01205 | Dice: 0.993 | Time: 0.4833
# Training Epoch 62: | Loss: 0.00682 | Dice: 0.996 | Time: 6.1833
# Validation Epoch 62: | Loss: 0.02103 | Dice: 0.985 | Time: 0.4833
# Training Epoch 63: | Loss: 0.00682 | Dice: 0.996 | Time: 6.0333
# Validation Epoch 63: | Loss: 0.01199 | Dice: 0.994 | Time: 0.4833
# Training Epoch 64: | Loss: 0.00766 | Dice: 0.995 | Time: 5.9333
# Validation Epoch 64: | Loss: 0.02043 | Dice: 0.986 | Time: 0.5
# Training Epoch 65: | Loss: 0.01924 | Dice: 0.987 | Time: 5.8667
# Validation Epoch 65: | Loss: 0.01616 | Dice: 0.991 | Time: 0.4833
# Training Epoch 66: | Loss: 0.00766 | Dice: 0.995 | Time: 6.1833
# Validation Epoch 66: | Loss: 0.01190 | Dice: 0.993 | Time: 0.5333
# Training Epoch 67: | Loss: 0.00688 | Dice: 0.995 | Time: 6.2
# Validation Epoch 67: | Loss: 0.01066 | Dice: 0.994 | Time: 0.5167
# Training Epoch 68: | Loss: 0.00724 | Dice: 0.995 | Time: 6.2
# Validation Epoch 68: | Loss: 0.00969 | Dice: 0.994 | Time: 0.55
# Training Epoch 69: | Loss: 0.00639 | Dice: 0.996 | Time: 6.5833
# Validation Epoch 69: | Loss: 0.00918 | Dice: 0.994 | Time: 0.55
# Training Epoch 70: | Loss: 0.00642 | Dice: 0.996 | Time: 6.35
# Validation Epoch 70: | Loss: 0.01129 | Dice: 0.992 | Time: 0.4833
# Training Epoch 71: | Loss: 0.00631 | Dice: 0.996 | Time: 6.35
# Validation Epoch 71: | Loss: 0.00917 | Dice: 0.995 | Time: 0.4
# Training Epoch 72: | Loss: 0.00654 | Dice: 0.996 | Time: 6.0
# Validation Epoch 72: | Loss: 0.01229 | Dice: 0.991 | Time: 0.5
# Training Epoch 73: | Loss: 0.00657 | Dice: 0.996 | Time: 6.0333
# Validation Epoch 73: | Loss: 0.01080 | Dice: 0.993 | Time: 0.5
# Training Epoch 74: | Loss: 0.00631 | Dice: 0.996 | Time: 5.7833
# Validation Epoch 74: | Loss: 0.01235 | Dice: 0.992 | Time: 0.4667
# Training Epoch 75: | Loss: 0.00651 | Dice: 0.996 | Time: 5.9333
# Validation Epoch 75: | Loss: 0.01137 | Dice: 0.992 | Time: 0.55
# Training Epoch 76: | Loss: 0.00628 | Dice: 0.996 | Time: 5.8167
# Validation Epoch 76: | Loss: 0.00901 | Dice: 0.994 | Time: 0.5
# Training Epoch 77: | Loss: 0.02807 | Dice: 0.979 | Time: 5.8167
# Validation Epoch 77: | Loss: 0.01415 | Dice: 0.991 | Time: 0.5167
# Training Epoch 78: | Loss: 0.00690 | Dice: 0.995 | Time: 5.75
# Validation Epoch 78: | Loss: 0.01535 | Dice: 0.988 | Time: 0.5
# Training Epoch 79: | Loss: 0.00594 | Dice: 0.996 | Time: 5.8667
# Validation Epoch 79: | Loss: 0.01885 | Dice: 0.985 | Time: 0.5333
# Training Epoch 80: | Loss: 0.00728 | Dice: 0.995 | Time: 5.6333
# Validation Epoch 80: | Loss: 0.00798 | Dice: 0.995 | Time: 0.5333
# Training Epoch 81: | Loss: 0.00567 | Dice: 0.996 | Time: 6.1167
# Validation Epoch 81: | Loss: 0.01537 | Dice: 0.988 | Time: 0.5167
# Training Epoch 82: | Loss: 0.00574 | Dice: 0.996 | Time: 5.6167
# Validation Epoch 82: | Loss: 0.01078 | Dice: 0.993 | Time: 0.4667
# Training Epoch 83: | Loss: 0.00570 | Dice: 0.996 | Time: 5.8667
# Validation Epoch 83: | Loss: 0.01594 | Dice: 0.987 | Time: 0.4833
# Training Epoch 84: | Loss: 0.00563 | Dice: 0.996 | Time: 5.6833
# Validation Epoch 84: | Loss: 0.01400 | Dice: 0.989 | Time: 0.5
# Training Epoch 85: | Loss: 0.00567 | Dice: 0.996 | Time: 5.6167
# Validation Epoch 85: | Loss: 0.01988 | Dice: 0.983 | Time: 0.5
# Training Epoch 86: | Loss: 0.00572 | Dice: 0.996 | Time: 5.7833
# Validation Epoch 86: | Loss: 0.00701 | Dice: 0.996 | Time: 0.5333
# Training Epoch 87: | Loss: 0.00927 | Dice: 0.995 | Time: 5.6
# Validation Epoch 87: | Loss: 0.27124 | Dice: 0.787 | Time: 0.5167
# Training Epoch 88: | Loss: 0.00931 | Dice: 0.994 | Time: 5.1833
# Validation Epoch 88: | Loss: 0.00914 | Dice: 0.994 | Time: 0.4833
# Training Epoch 89: | Loss: 0.00576 | Dice: 0.996 | Time: 4.8167
# Validation Epoch 89: | Loss: 0.01038 | Dice: 0.993 | Time: 0.45
# Training Epoch 90: | Loss: 0.00535 | Dice: 0.996 | Time: 4.1
# Validation Epoch 90: | Loss: 0.00706 | Dice: 0.996 | Time: 0.3833
# Training Epoch 91: | Loss: 0.00525 | Dice: 0.997 | Time: 4.3667
# Validation Epoch 91: | Loss: 0.00749 | Dice: 0.995 | Time: 0.5
# Training Epoch 92: | Loss: 0.00515 | Dice: 0.997 | Time: 4.7333
# Validation Epoch 92: | Loss: 0.00966 | Dice: 0.993 | Time: 0.4667
# Training Epoch 93: | Loss: 0.00504 | Dice: 0.997 | Time: 4.5833
# Validation Epoch 93: | Loss: 0.02257 | Dice: 0.980 | Time: 0.45
# Training Epoch 94: | Loss: 0.00528 | Dice: 0.997 | Time: 4.75
# Validation Epoch 94: | Loss: 0.00979 | Dice: 0.993 | Time: 0.45
# Training Epoch 95: | Loss: 0.00525 | Dice: 0.997 | Time: 4.8
# Validation Epoch 95: | Loss: 0.01244 | Dice: 0.990 | Time: 0.4667
# Training Epoch 96: | Loss: 0.00520 | Dice: 0.997 | Time: 4.95
# Validation Epoch 96: | Loss: 0.00900 | Dice: 0.994 | Time: 0.5
# Training Epoch 97: | Loss: 0.00527 | Dice: 0.997 | Time: 5.1
# Validation Epoch 97: | Loss: 0.01597 | Dice: 0.987 | Time: 0.4833
# Training Epoch 98: | Loss: 0.00868 | Dice: 0.995 | Time: 5.05
# Validation Epoch 98: | Loss: 0.00869 | Dice: 0.995 | Time: 0.4167
# Training Epoch 99: | Loss: 0.00508 | Dice: 0.997 | Time: 4.8833
# Validation Epoch 99: | Loss: 0.01301 | Dice: 0.990 | Time: 0.4833
# Training Epoch 100: | Loss: 0.00488 | Dice: 0.997 | Time: 5.0167
# Validation Epoch 100: | Loss: 0.00948 | Dice: 0.993 | Time: 0.4667
# Total time : 621

# %% [markdown]
# # Saving and visualization

# %%
def train_vis(training_stats):

    ### Plotting Results
    train_logs = training_stats['train logs']
    val_logs = training_stats['validation logs']
    epochs = training_stats['current epoch'] + 1
    best_epoch = training_stats['best epoch'] 

#Loss
    plt.figure(figsize=(15, 6))
    
    plt.title("Loss",color='black')
    plt.plot(np.arange(1, epochs), train_logs["loss"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["loss"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch,color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Loss", color = 'black')
    plt.show()

# dice coefficient
    plt.figure(figsize=(15, 6))
    plt.title("Dice", color='black')
    plt.plot(np.arange(1, epochs), train_logs["dice coefficient"], color = 'blue', label='Training')
    plt.plot(np.arange(1, epochs), val_logs["dice coefficient"], color = 'orange', label='Validation')
    plt.axvline(x=best_epoch, color='green')
    plt.xticks(ticks=range(1, epochs), color='black')
    plt.yticks(color='black')
    plt.xlabel("Epochs", color = 'black')
    plt.ylabel("Accuracy", color='black')
    plt.show()

# %%
train_vis(training_stats)

# %%
# Saving the best model
def save_model(model, model_name, training_stats, parameters, img_lists):
    ''' Save model either for inference or for continuing training '''
    torch.save({'model_name': model_name,
                'model_state_dict': model.state_dict(),
                'parameters': (resize_size, n_channels, num_categories)
                }, f'{project_name}_{model_name}_inference.pt')
        
    torch.save({'model_name': model_name,
                'model_state_dict': model.state_dict(),
                'model_stats': training_stats,
                'parameters': (resize_size, n_channels, num_categories),
                'img_lists': img_lists
                }, f'{project_name}_{model_name}.pt')
    mylogs.info("Model saved")

# %%
img_lists = (train_img_mask_pairs, val_img_mask_pairs, test_img_mask_pairs)
save_model(model, model_name, training_stats, (resize_size, n_channels,num_categories),  img_lists)
# Out:
# Model saved

# %%
# Testing on a random test image 
def model_inference_preview(test_data_loader, label_values):
    for image,_ , actual_mask in test_data_loader:
        image.to('cpu')
        actual_mask.to('cpu')
        model.to('cpu')
        prediction_mask = model(image)
        prediction_mask = prediction_mask.permute(0,2,3,1)
   
        #### actual mask
        _, actual_masked_image = apply_color_masks(image, actual_mask,label_values)
        
        actual_masked_image = torch.from_numpy(actual_masked_image)
        actual_masked_image = actual_masked_image.squeeze()
        
        #### predicted mask
        _, predicted_masked_image = apply_color_masks(image, prediction_mask.detach(), label_values)
        predicted_masked_image = torch.from_numpy(predicted_masked_image)
        predicted_masked_image = predicted_masked_image.squeeze()
        
        imgs = [actual_masked_image, predicted_masked_image]
        # https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib by YellowPillow
        n_row = 1
        n_col = 2
        _, axs = plt.subplots(n_row, n_col, figsize=(18, 18))
        axs = axs.flatten()
        titles = [' Actual Mask', 'Predicted Mask']
        for title, img, ax in zip(titles, imgs, axs):
            ax.imshow(make_grid(img, 4))
            ax.set_title(title)
        plt.show()
        
        #saving
        break

model_inference_preview(test_data_loader,label_values)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
